# %%
import os
import tempfile
import zipfile
from pathlib import Path

import pandas as pd

# %%
data_path = Path(os.environ["DATA_PATH"])

# %%
with (
    zipfile.ZipFile(data_path / "raws" / "INE" / "PRESIDENCIA_2024.zip") as zf,
    tempfile.TemporaryDirectory() as tmpdir,
):
    zf.extractall(tmpdir)
    fpath = Path(tmpdir) / "PRESIDENCIA_2024" / "CSV" / "2024_SEE_PRE_NAL_SEC.csv"
    df = pd.read_csv(fpath, encoding="latin1")

df.columns = df.columns.str.replace("ï»¿", "")
df = df.assign(
    CVEGEO=lambda df: (
        df["ID_ESTADO"].astype(str).str.zfill(2)
        + df["ID_MUNICIPIO"].astype(str).str.zfill(3)
    )
)

# %%
parties = [
    "PAN",
    "PRI",
    "PRD",
    "MORENA",
    "MC",
    "PVEM",
    "PT",
]
vote_cols = [c for c in df.columns if any(p in c for p in parties)]

# %%
df
# Out:
#        CIRCUNSCRIPCION  ID_ESTADO   NOMBRE_ESTADO  ID_DISTRITO_FEDERAL  \
# 0                    2          1  AGUASCALIENTES                    0
# 1                    2          1  AGUASCALIENTES                    1
# 2                    2          1  AGUASCALIENTES                    1
# 3                    2          1  AGUASCALIENTES                    1
# 4                    2          1  AGUASCALIENTES                    1
# ...                ...        ...             ...                  ...
# 70531                2         32       ZACATECAS                    4
# 70532                2         32       ZACATECAS                    4
# 70533                2         32       ZACATECAS                    4
# 70534                2         32       ZACATECAS                    4
# 70535                2         32       ZACATECAS                    4
#
#       CABECERA_DISTRITAL_FEDERAL  ID_MUNICIPIO              MUNICIPIO  \
# ...

# %%
df[vote_cols].sum(axis=1)
# Out:
# 0        2073
# 1        1188
# 2        1291
# 3        1133
# 4        1613
#          ...
# 70531     719
# 70532     616
# 70533     651
# 70534     744
# 70535    1016
# Length: 70536, dtype: int64
