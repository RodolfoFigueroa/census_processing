# %%
import geopandas as gpd

# %%
df = gpd.read_file("./malla_niveles_4_al_9_continental_e_islas.gpkg")
# Out:
# c:\Users\lain\Documents\census_processing\.venv\Lib\site-packages\pyogrio\geopandas.py:275: UserWarning: More than one layer found in 'malla_niveles_4_al_9_continental_e_islas.gpkg': 'n4' (default), 'n5', 'n6', 'n7', 'n8', 'n9'. Specify layer parameter to avoid this warning.
#   result = read_func(

# %%
df
# Out:
#     codigo                                           geometry
# 0    O2065  POLYGON ((-117.77778 33.52473, -116.66667 33.5...
# 1    O2073  POLYGON ((-116.66667 33.52473, -115.55556 33.5...
# 2    O2074  POLYGON ((-115.55556 33.52473, -114.44444 33.5...
# 3    O2068  POLYGON ((-117.77778 32.40034, -116.66667 32.4...
# 4    O2076  POLYGON ((-116.66667 32.40034, -115.55556 32.4...
# ..     ...                                                ...
# 228  O2872  POLYGON ((-94.44444 15.79325, -93.33333 15.793...
# 229  O2880  POLYGON ((-93.33333 15.79325, -92.22222 15.793...
# 230  O2881  POLYGON ((-92.22222 15.79325, -91.11111 15.793...
# 231  O2883  POLYGON ((-93.33333 14.8137, -92.22222 14.8137...
# 232  O2884  POLYGON ((-92.22222 14.8137, -91.11111 14.8137...
#
# [233 rows x 2 columns]
