# %%
import os
from pathlib import Path

import geopandas as gpd
import pandas as pd
import sqlalchemy

# %%
engine = sqlalchemy.create_engine(
    f"postgresql+psycopg2://{os.environ['POSTGRES_USER']}:{os.environ['POSTGRES_PASSWORD']}@{os.environ['POSTGRES_HOST']}:{os.environ['POSTGRES_PORT']}/{os.environ['POSTGRES_DB']}"
)

# %%
data_path = Path(os.environ["DATA_PATH"])

# %%
df_1995 = gpd.read_file(data_path / "raws" / "1995" / "Municipios_1995.shp").assign(
    cvegeo=lambda df: (
        df["CVE_ENT"].astype(str).str.zfill(2) + df["CVE_MUN"].astype(str).str.zfill(3)
    )
)
df_1990 = pd.read_csv(
    data_path / "raws" / "1990" / "ITER_NALTXT90.txt", sep="\t", encoding="latin-1"
)
# Out:
# C:\Users\lain\AppData\Local\Temp\ipykernel_30220\2138658618.py:2: DtypeWarning: Columns (6,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_1990 = pd.read_csv(data_path / "raws" / "1990" / "ITER_NALTXT90.txt", sep="\t", encoding="latin-1")

# %%
temp = df_1990.loc[lambda df: df["mun"] != 0]
muns_1990 = set(
    (temp["entidad"].astype(str).str.zfill(2) + temp["mun"].astype(str).str.zfill(3))
    .unique()
    .tolist()
)

# %%
muns_1995 = set(df_1995["cvegeo"].unique().tolist())

# %%
print(
    "\n".join(
        [
            "-" + " - ".join(x)
            for x in df_1995.loc[
                lambda df: df["cvegeo"].isin(muns_1995 - muns_1990),
                ["NOM_ENT", "NOM_MUN"],
            ].to_numpy()
        ]
    )
)
# Out:
# -Aguascalientes - Llano, El
# -Aguascalientes - San Francisco de los Romo
# -Baja California - Playas de Rosarito
# -Baja California Sur - Loreto
# -Guerrero - Acatepec
# -México - Valle de Chalco Solidaridad
# -Quintana Roo - Solidaridad
# -San Luis Potosí - Matlapa
# -San Luis Potosí - Naranjo, El
# -Tlaxcala - Benito Juárez
# -Tlaxcala - Emiliano Zapata
# -Tlaxcala - Lázaro Cárdenas
# -Tlaxcala - Magdalena Tlaltelulco, La
# -Tlaxcala - San Damián Texoloc
# -Tlaxcala - San Francisco Tetlanohcan
# -Tlaxcala - San Jerónimo Zacualpan
# -Tlaxcala - San José Teacalco
# -Tlaxcala - San Juan Huactzinco
# -Tlaxcala - San Lorenzo Axocomanitla
# -Tlaxcala - San Lucas Tecopilco
# -Tlaxcala - Santa Ana Nopalucan
# -Tlaxcala - Santa Apolonia Teacalco
# -Tlaxcala - Santa Catarina Ayometla
# -Tlaxcala - Santa Cruz Quilehtla
# -Tlaxcala - Santa Isabel Xiloxoxtla

# %%
df_1990.loc[lambda df: (df["entidad"] == 29) & (df["mun"] != 0) & (df["loc"] == 0)]
# Out:
#         entidad   nom_ent  mun                                  nom_mun  loc  \
# 135263       29  Tlaxcala    1                       Amaxac de Guerrero    0
# 135268       29  Tlaxcala    2          Apetatitlán de Antonio Carvajal    0
# 135273       29  Tlaxcala    3                             Atlangatepec    0
# 135303       29  Tlaxcala    4                              Atltzayanca    0
# 135350       29  Tlaxcala    5                                  Apizaco    0
# 135360       29  Tlaxcala    6                              Calpulalpan    0
# 135436       29  Tlaxcala    7                   El Carmen Tequexquitla    0
# 135441       29  Tlaxcala    8                               Cuapiaxtla    0
# 135472       29  Tlaxcala    9                               Cuaxomulco    0
# 135478       29  Tlaxcala   10                              Chiautempan    0
# 135489       29  Tlaxcala   11                  Muñoz de Domingo Arenas    0
# ...

# %%
df_1990[
    lambda df: (
        (df["loc"] == 0) & (df["nom_mun"].str.casefold().str.contains("tetlatlahuca"))
    )
]
# Out:
#         entidad   nom_ent  mun       nom_mun  loc          nom_loc longitud  \
# 135933       29  Tlaxcala   32  Tetlatlahuca    0  TOTAL MUNICIPAL      NaN
#
#         latitud  altitud  p_total  ...  prom_cua pared_la techo_la piso_tie  \
# 135933      NaN      NaN  15801.0  ...      1.68        9       90     2544
#
#        viv_1_c viv_2_c c_agua_ent c_drenaje c_e_elect viv_pprop
# 135933     249     491       2576      1452      2747      2686
#
# [1 rows x 46 columns]

# %%
muns_1995 - muns_1990
# Out:
# {'01010',
#  '01011',
#  '02005',
#  '03009',
#  '12076',
#  '15122',
#  '23008',
#  '24057',
#  '24058',
#  '29045',
#  '29046',
#  '29047',
#  '29048',
#  '29049',
#  '29050',
#  '29051',
#  '29052',
#  '29053',
#  '29054',
#  '29055',
#  '29056',
#  '29057',
#  '29058',
#  '29059',
#  '29060'}
