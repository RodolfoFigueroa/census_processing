# %%
import pandas as pd

# %%
df = pd.read_csv(
    "/Users/rodolfofigueroa/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/census_processing_data/raws/1990/ITER_NALTXT90.txt",
    sep="\t",
    encoding="latin1",
)
# Out:
# /var/folders/yq/0mz24vy927s9m5vjh6gqb6040000gn/T/ipykernel_95730/4265471094.py:1: DtypeWarning: Columns (6,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/rodolfofigueroa/Library/CloudStorage/OneDrive-InstitutoTecnologicoydeEstudiosSuperioresdeMonterrey/census_processing_data/raws/1990/ITER_NALTXT90.txt", sep="\t", encoding="latin1")

# %%
from pathlib import Path

Path("a", "b")
# Out:
# PosixPath('a/b')
