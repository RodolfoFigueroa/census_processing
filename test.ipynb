# %%
import os

import geopandas as gpd
import sqlalchemy

from census_processing.defs.assets.income.income import full_graph

# %%
full_graph()
# Out:
# ---------------------------------------------------------------------------
# DagsterInvariantViolationError            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 full_graph()
#
# File c:\Users\lain\Documents\census_processing\.venv\Lib\site-packages\dagster\_core\definitions\node_definition.py:203, in NodeDefinition.__call__(self, *args, **kwargs)
#     202 def __call__(self, *args: object, **kwargs: object) -> object:
# --> 203     return self.get_pending_invocation()(*args, **kwargs)
#
# File c:\Users\lain\Documents\census_processing\.venv\Lib\site-packages\dagster\_core\definitions\composition.py:411, in PendingNodeInvocation.__call__(self, *args, **kwargs)
#     406 if not is_in_composition() and isinstance(self.node_def, OpDefinition):
#     407     return direct_invocation_result(
#     408         cast("PendingNodeInvocation[OpDefinition]", self), *args, **kwargs
#     409     )
# --> 411 assert_in_composition(node_name, self.node_def)
# ...

# %%
engine = sqlalchemy.create_engine(
    f"postgresql+psycopg2://{os.environ['POSTGRES_USER']}:{os.environ['POSTGRES_PASSWORD']}@{os.environ['POSTGRES_HOST']}:{os.environ['POSTGRES_PORT']}/{os.environ['POSTGRES_DB']}"
)

# %%
with engine.connect() as conn:
    df = gpd.read_postgis(
        """
        SELECT 
            census_2020_ageb.pobtot,
            income,
            income_pc,
            metropoli_2020.nom_met,
            census_2020_ageb.geometry
        FROM income_2020
        INNER JOIN census_2020_ageb
            ON income_2020.cvegeo = census_2020_ageb.cvegeo
        INNER JOIN census_2020_mun
            ON census_2020_mun.cvegeo = census_2020_ageb.cve_mun
        INNER JOIN metropoli_2020
            ON metropoli_2020.cve_met = census_2020_mun.cve_met
        """,
        conn,
        geom_col="geometry",
    )

# %%
df.groupby("nom_met").agg({"pobtot": "sum", "income": "sum"}).assign(
    income_pc=lambda df: df["income"] / df["pobtot"]
).sort_values("income_pc", ascending=False)
# Out:
#                         pobtot        income     income_pc
# nom_met
# Tijuana                1957127  4.444946e+10  22711.585590
# Ensenada                363146  8.103949e+09  22315.951535
# La Paz                  234304  5.170656e+09  22068.151277
# Hermosillo              797173  1.738705e+10  21810.884803
# Mexicali                900452  1.954509e+10  21705.866782
# ...                        ...           ...           ...
# Acapulco                549947  6.064261e+09  11026.990866
# Orizaba                 361462  3.977226e+09  11003.163593
# Tulancingo              165258  1.728169e+09  10457.402218
# Tapachula               244882  2.361824e+09   9644.743200
# San Martín Texmelucan   262254  2.488304e+09   9488.144270
#
# [70 rows x 3 columns]
