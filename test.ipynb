# %%
import json
import os

import geopandas as gpd
import requests
from websockets.sync.client import connect

# %%
# LYRA_HOST = os.environ["LYRA_HOST"]
LYRA_HOST = "localhost:5219"

WS_URL = f"ws://{LYRA_HOST}/ws/tree_coverage/geojson"
HTTP_BASE_URL = f"http://{LYRA_HOST}"

# %%
df = gpd.read_file(
    r"C:\Users\lain\OneDrive - Instituto Tecnologico y de Estudios Superiores de Monterrey\mexicali_data\generated\agebs.gpkg"
)
test = json.loads(df[["geometry"]].reset_index(names="cvegeo").to_json())

# %%
auth_headers = {
    "P-Access-Token-Id": os.environ["PANGOLIN_ACCES_TOKEN_ID"],
    "P-Access-Token": os.environ["PANGOLIN_ACCESS_TOKEN"],
}

with connect(
    WS_URL,
    additional_headers=auth_headers,
) as websocket:
    request_payload = {"function_name": "tree_coverage", "geojson": test}
    websocket.send(json.dumps(request_payload))

    ack_str = websocket.recv()
    ack = json.loads(ack_str)
    print(f"Server acknowledged. Task ID: {ack.get('task_id')}")

    notification_str = websocket.recv()
    notification = json.loads(notification_str)
    status = notification["status"]

    if status == "error":
        print(f"Worker failed: {notification.get('message')}")

    elif status == "success":
        download_id = notification.get("download_id")
        print(f"Worker finished. Received download ticket: {download_id}")

        print("Downloading data via HTTP...")
        download_url = f"{HTTP_BASE_URL}/download-result/{download_id}"
        response = requests.get(download_url, timeout=100, headers=auth_headers)

        if response.status_code == 200:
            final_data = response.json()
            print("Download complete!")
        else:
            print(f"Failed to download data. HTTP {response.status_code}")
# Out:
# Server acknowledged. Task ID: e09c2d6c-5738-49d9-82b8-f6c0959f6543
# Worker finished. Received download ticket: e09c2d6c-5738-49d9-82b8-f6c0959f6543
# Downloading data via HTTP...
# Download complete!

# %%
final_data
# Out:
# {'status': 'success',
#  'result': {'0': 321.3636517693015,
#   '1': 0.0,
#   '2': 685.9606840245865,
#   '3': 27617.50647235945,
#   '4': 29253.44726634306,
#   '5': 77810.39089882046,
#   '6': 53535.96128073299,
#   '7': 33607.869860121784,
#   '8': 29282.50751546224,
#   '9': 51229.39269445084,
#   '10': 4782.550428442862,
#   '11': 14857.704768162148,
#   '12': 18351.307772049247,
#   '13': 61423.63283906824,
#   '14': 20137.203737027037,
#   '15': 12928.23257003485,
#   '16': 30270.69722230201,
#   '17': 14273.95178605622,
#   '18': 26377.824042825137,
#   '19': 17944.297858982467,
#   '20': 19003.784647144992,
#   '21': 5772.8662109375,
#   '22': 29654.158944642313,
#   '23': 79593.81447035845,
#   '24': 8396.907165527344,
#   '25': 22688.650108666512,
#   '26': 15834.356088915058,
#   '27': 33148.13211789599,
#   '28': 17944.069923071766,
#   '29': 20557.279567583868,
#   '30': 14008.021712239584,
#   '31': 21518.10596852022,
#   '32': 0.0,
#   '33': 0.0,
#   '34': 7939.546287147672,
#   '35': 36160.26331164789,
#   '36': 17562.15218266506,
#   '37': 41151.53596622243,
#   '231': 22226.38259516697,
#   '232': 16938.97590092678,
#   '233': 12920.836908318015,
#   '234': 7927.043089623545,
#   '235': 29312.696560489432,
#   '236': 21833.905764591,
#   '237': 19523.03749162263,
#   '238': 5798.039836569394,
#   '239': 8394.356189922259,
#   '240': 7550.355398380054,
#   '241': 49345.28755959903,
#   '242': 5524.621395814184,
#   '243': 525.1060180664062,
#   '244': 1000.7321748621323,
#   '245': 7220.897172277114,
#   '246': 18176.411336023666,
#   '247': 9042.813355210248,
#   '248': 8724.088113941865,
#   '249': 9577.493774414062,
#   '250': 41176.88912066292,
#   '251': 3722.2954838771448,
#   '252': 6250.669582232307,
#   '253': 9450.0869140625,
#   '254': 27823.12082758885,
#   '255': 3675.2413330078125,
#   '256': 37426.22770014744,
#   '257': 13127.515197753906,
#   '258': 4725.829040527344,
#   '259': 15440.674347043505,
#   '260': 3196.171569106158,
#   '261': 1575.4031982421875,
#   '262': 1574.4164428710938,
#   '263': 1057.824196729473,
#   '264': 11423.16828397863,
#   '265': 9449.25537109375,
#   '266': 1049.935791015625,
#   '267': 3308.5001086665134,
#   '268': 27627.441303088617,
#   '269': 6157.253927552467,
#   '270': 3459.704447667739,
#   '271': 1458.0658811083026,
#   '272': 33023.1010476505,
#   '273': 21501.873283835015,
#   '274': 0.0,
#   '275': 127.67558091107537,
#   '276': 1536.2907145182292,
#   '277': 4673.052519674862,
#   '278': 11096.553551767385,
#   '279': 10720.801561781938,
#   '280': 3110.6502620921415,
#   '281': 3149.7039184570312,
#   '282': 5576.820586081112,
#   '283': 5771.295075779335,
#   '284': 9138.080587708717,
#   '285': 524.7921752929688,
#   '286': 53144.958274213015,
#   '287': 27259.828248027727,
#   '288': 0.0,
#   '289': 525.171875,
#   '290': 5095.285750804228,
#   '291': 3486.0823802274813,
#   '292': 13349.204356474032,
#   '293': 15713.841963943782,
#   '294': 6852.984496830959,
#   '295': 11019.965759277344,
#   '296': 11381.168734202665,
#   '297': 831.4121309168199,
#   '298': 4971.793715772442,
#   '299': 3960.8109547334557,
#   '300': 4199.637023925781,
#   '301': 4447.877738204656,
#   '302': 4725.992919921875,
#   '303': 953.539080212163,
#   '304': 0.0,
#   '305': 3627.0322782628677,
#   '306': 525.1937866210938,
#   '307': 2100.247314453125,
#   '308': 13323.525688620175,
#   '309': 0.0,
#   '310': 10471.414960075828,
#   '311': 4110.466182693781,
#   '312': 25477.31368384268,
#   '313': 13856.02409715839,
#   '314': 7615.931573845359,
#   '315': 21260.624395392922,
#   '316': 1255.6617359834559,
#   '317': 2553.718412511489,
#   '318': 2063.274997127757,
#   '319': 21008.08481732537,
#   '320': 9720.405695178462,
#   '321': 524.8399658203125,
#   '322': 9902.561273073683,
#   '323': 14759.266418457031,
#   '324': 9445.357666015625,
#   '325': 5303.20079273897,
#   '326': 3280.7943711224725,
#   '327': 3150.2036743164062,
#   '328': 1050.1036376953125,
#   '329': 1836.6821743834253,
#   '330': 13574.727556774662,
#   '331': 8971.99205753102,
#   '332': 4201.040588378906,
#   '333': 5184.419942698759,
#   '334': 3676.1358642578125,
#   '335': 0.0,
#   '336': 17084.03928126915,
#   '337': 6053.800411448759,
#   '338': 2811.730726773131,
#   '339': 2139.819355564491,
#   '340': 0.0,
#   '341': 525.2196044921875,
#   '342': 0.0,
#   '343': 3150.3353881835938,
#   '344': 525.1654052734375,
#   '345': 23079.950969621248,
#   '346': 11546.383728027344,
#   '347': 12594.549414541207,
#   '348': 2099.706298828125,
#   '349': 8339.229237275966,
#   '350': 2791.9500287224264,
#   '351': 2625.0679931640625,
#   '352': 2394.682391716452,
#   '353': 5708.32174838197,
#   '354': 656.6466263116574,
#   '355': 9114.45519133923,
#   '356': 3673.7969360351562,
#   '357': 17232.01576693666,
#   '358': 6827.208190917969,
#   '359': 11341.792565678616,
#   '360': 0.0,
#   '361': 0.0,
#   '362': 0.0,
#   '363': 524.8322143554688,
#   '364': 2624.8948974609375,
#   '365': 13962.030384258198,
#   '366': 10887.438195322075,
#   '367': 3005.396705537684,
#   '368': 12340.099926039751,
#   '369': 6543.881377814798,
#   '370': 6300.0758056640625,
#   '371': 1348.8909677542892,
#   '372': 0.0,
#   '373': 0.0,
#   '374': 0.0,
#   '375': 2633.791415345435,
#   '376': 0.0,
#   '377': 218.14243451286765,
#   '378': 1297.6433988683366,
#   '379': 1083.48063510072,
#   '380': 8067.112553615196,
#   '381': 1574.3571166992188,
#   '382': 0.0,
#   '383': 525.104736328125,
#   '384': 1559.9908222273284,
#   '385': 0.0,
#   '386': 0.0,
#   '387': 1346.7397834329045,
#   '388': 1123.7220918543198,
#   '389': 10297.522714173561,
#   '390': 5692.152164713542,
#   '391': 3685.8884480794272,
#   '392': 525.1150512695312,
#   '393': 3214.486087095971,
#   '394': 0.0,
#   '395': 0.0,
#   '396': 2624.012451171875,
#   '397': 1021.712701775046,
#   '398': 1198.8085322361367,
#   '399': 1880.6724927715225,
#   '400': 391.2468237783395,
#   '401': 0.0,
#   '402': 2584.1797748640474,
#   '403': 0.0,
#   '404': 0.0,
#   '405': 131.825,
#   '406': 1574.933349609375,
#   '407': 0.0,
#   '408': 2103.397083716299,
#   '409': 687.7907465916054,
#   '410': 0.0,
#   '411': 1050.1578369140625,
#   '412': 0.0,
#   '413': 0.0,
#   '414': 168863.25433062384,
#   '415': 2129.0916764801623,
#   '416': 19984.15456590839,
#   '417': 10918.791190831802,
#   '418': 1864.0387293198528,
#   '419': 0.0,
#   '420': 559.9986531575521,
#   '421': 20627.186722579656,
#   '422': 0.0,
#   '423': 327.18221650965074,
#   '424': 0.0,
#   '425': 0.0,
#   '426': 0.0,
#   '427': 168.91324989468444,
#   '428': 1694.7195571001837,
#   '429': 37572.726171874994,
#   '430': 43643.572287406176}}
