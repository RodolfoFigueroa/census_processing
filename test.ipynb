# %%
import json
import os

import geopandas as gpd
import requests
from websockets.sync.client import connect

# %%
# LYRA_HOST = os.environ["LYRA_HOST"]
LYRA_HOST = "localhost:5219"

WS_URL = f"ws://{LYRA_HOST}/ws/tree_coverage/geojson"
HTTP_BASE_URL = f"http://{LYRA_HOST}"

# %%
df = gpd.read_file(
    r"C:\Users\lain\OneDrive - Instituto Tecnologico y de Estudios Superiores de Monterrey\mexicali_data\generated\agebs.gpkg"
)
test = json.loads(df[["geometry"]].reset_index(names="cvegeo").to_json())

# %%
auth_headers = {
    "P-Access-Token-Id": os.environ["PANGOLIN_ACCES_TOKEN_ID"],
    "P-Access-Token": os.environ["PANGOLIN_ACCESS_TOKEN"],
}


def foo():
    with connect(
        WS_URL,
        additional_headers=auth_headers,
    ) as websocket:
        temp = df["CVEGEO"].tolist()
        request_payload = {"data": {"data_type": "cvegeo_list", "value": temp}}
        websocket.send(json.dumps(request_payload))

        ack_str = websocket.recv()
        ack = json.loads(ack_str)

        if ack["status"] == "error":
            err = (
                f"Server error. Type: {ack.get('type')}. Details: {ack.get('details')}"
            )
            raise ValueError(err)

        print(f"Server acknowledged. Task ID: {ack.get('task_id')}")

        notification_str = websocket.recv()
        notification = json.loads(notification_str)
        status = notification["status"]

        if status == "error":
            print(f"Worker failed: {notification.get('message')}")

        elif status == "success":
            download_id = notification.get("download_id")
            print(f"Worker finished. Received download ticket: {download_id}")

            print("Downloading data via HTTP...")
            download_url = f"{HTTP_BASE_URL}/download-result/{download_id}"
            response = requests.get(download_url, timeout=100, headers=auth_headers)

            if response.status_code == 200:
                final_data = response.json()
                print("Download complete!")
                return final_data
            print(f"Failed to download data. HTTP {response.status_code}")
        return None


dat = foo()
# Out:
# Server acknowledged. Task ID: 4109dde9-5844-40a6-aac6-f1061e8c5ca4
# Worker finished. Received download ticket: 4109dde9-5844-40a6-aac6-f1061e8c5ca4
# ...
# Download complete!

# %%
dat
# Out:
# {'status': 'success',
#  'result': {'0200200010019': 321.3636517693015,
#   '0200200010023': 0.0,
#   '0200200010038': 685.9606840245865,
#   '0200200010042': 27617.50647235945,
#   '0200200010057': 29253.44726634306,
#   '0200200010095': 77810.39089882046,
#   '0200200010108': 53535.96128073299,
#   '0200200010165': 33607.869860121784,
#   '020020001017A': 29282.50751546224,
#   '0200200010184': 51229.39269445084,
#   '0200200010220': 4782.550428442862,
#   '0200200010269': 14857.704768162148,
#   '0200200010273': 18351.307772049247,
#   '0200200010288': 61423.63283906824,
#   '0200200010292': 20137.203737027037,
#   '0200200010305': 12928.23257003485,
#   '020020001031A': 30270.69722230201,
#   '0200200010324': 14273.95178605622,
#   '0200200010339': 26377.824042825137,
#   '0200200010362': 17944.297858982467,
#   '0200200010377': 19003.784647144992,
#   '0200200010381': 5772.8662109375,
#   '0200200010409': 29654.158944642313,
#   '0200200010413': 79593.81447035845,
# ...
